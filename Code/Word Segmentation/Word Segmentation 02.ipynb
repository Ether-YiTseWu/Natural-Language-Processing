# %%
import re

# %%
# read input txt and make it to str
txtInput = open('wsegInput_test.txt',encoding="utf-8")
strInput = txtInput.read()
print(strInput)

# check it's str type
print(type(strInput))
print('\n')

# split
splitInput = strInput.split()
print('splitInput length :',len(splitInput))
splitInput
# Out:
# 禿頭除與家族史有關，
# 毛囊炎也是一大原因，
# 如果頭皮摸起來好像長痘痘，
# 有一顆顆還伴隨刺痛，
# 就有可能是毛囊炎，
# 應少用太緊的帽子，
# 也避免安全帽戴太久，
# 以免毛囊炎惡化。
# 夏天或天熱時較易出現毛囊炎，
# 醫師確診後應會開立口服抗生素藥物；
# 若紅腫較少則塗抹外用藥膏即可望逐漸改善症狀。
# 美國總統川普昨在越南表示願意調停南海爭議，
# 隨後轉往菲律賓，展開亞洲之行最後一站行程，
# 參加東南亞及東亞國家的高峰會。
# 菲律賓總統杜特蒂昨重申別惹中國、擱置主權爭議的立場，
# 還說獲中國國家主席習近平保證會和平解決南海問題。
# 在南海建造7座人工島礁、部署飛彈戰機的中國，
# 想各個擊破南海周邊諸國，
# 堅拒「非當事國」也就是美國或日本介入、調停或仲裁，
# 美方堅持各國在南海享有自由航行與飛行權利，
# 日本也不想讓這條每年運送近100兆元台幣貨物的航線被中國納為內海。
#
# <class 'str'>
#
#
# splitInput length : 21
# ['禿頭除與家族史有關，',
#  '毛囊炎也是一大原因，',
#  '如果頭皮摸起來好像長痘痘，',
#  '有一顆顆還伴隨刺痛，',
#  '就有可能是毛囊炎，',
#  '應少用太緊的帽子，',
#  '也避免安全帽戴太久，',
#  '以免毛囊炎惡化。',
#  '夏天或天熱時較易出現毛囊炎，',
#  '醫師確診後應會開立口服抗生素藥物；',
#  '若紅腫較少則塗抹外用藥膏即可望逐漸改善症狀。',
#  '美國總統川普昨在越南表示願意調停南海爭議，',
#  '隨後轉往菲律賓，展開亞洲之行最後一站行程，',
#  '參加東南亞及東亞國家的高峰會。',
#  '菲律賓總統杜特蒂昨重申別惹中國、擱置主權爭議的立場，',
#  '還說獲中國國家主席習近平保證會和平解決南海問題。',
#  '在南海建造7座人工島礁、部署飛彈戰機的中國，',
#  '想各個擊破南海周邊諸國，',
#  '堅拒「非當事國」也就是美國或日本介入、調停或仲裁，',
#  '美方堅持各國在南海享有自由航行與飛行權利，',
#  '日本也不想讓這條每年運送近100兆元台幣貨物的航線被中國納為內海。']

# %%
# read dict txt and make it to str
txtDict = open('lexicon_test.txt',encoding="utf-8")
strDict = txtDict.read()

# check it's str type
print(type(strDict))

# split
splitDict = strDict.split()
splitDict
# Out:
# <class 'str'>
# ['100',
#  '7',
#  '、',
#  '。',
#  '「',
#  '」',
#  '一',
#  '一大',
#  '一顆顆',
#  '不',
#  '不想',
#  '中',
#  '中國',
#  '主',
#  '主席',
#  '主權',
#  '久',
#  '之',
#  '也',
#  '事',
#  '亞',
#  '亞洲',
#  '享',
#  '享有',
#  '人',
#  '人工',
#  '人工島礁',
#  '介',
#  '介入',
#  '以',
#  '以免',
#  '仲',
#  '仲裁',
#  '伴',
#  '伴隨',
#  '來',
#  '保',
#  '保證',
#  '個',
#  '停',
#  '像',
#  '元',
#  '兆',
#  '免',
#  '入',
#  '內',
#  '內海',
#  '全',
#  '出',
#  '出現',
#  '別',
#  '利',
#  '刺',
#  '刺痛',
#  '則',
#  '加',
#  '化',
#  '南',
#  '南亞',
#  '南海',
#  '即',
#  '即可',
#  '原',
#  '原因',
#  '參',
#  '參加',
#  '及',
#  '口',
#  '口服',
#  '可',
#  '可望',
#  '可能',
#  '台',
#  '台幣',
#  '史',
#  '各',
#  '周',
#  '周邊',
#  '和',
#  '和平',
#  '問',
#  '問題',
#  '善',
#  '囊',
#  '因',
#  '國',
#  '國家',
#  '在',
#  '堅',
#  '堅拒',
#  '堅持',
#  '場',
#  '塗',
#  '塗抹',
#  '夏',
#  '夏天',
#  '外',
#  '外用',
#  '大',
#  '天',
#  '太',
#  '好',
#  '好像',
#  '如',
#  '如果',
#  '子',
#  '安',
#  '安全',
#  '安全帽',
#  '家',
#  '家族',
#  '家族史',
#  '少',
#  '就',
#  '就是',
#  '展',
# ...

# %%
# def a function that next cell will need
def check(a,b,aStr):
    if len(a)==2:
        bb = aStr
    else:
        bb = b  
    return bb

# %%
# list the probable word sets
probableSets = []
tempWordList = []

for index in range(0,21):
    for word in splitInput[index]:
        for dictWords in splitDict:
            if word in dictWords and dictWords in splitInput[index] and dictWords not in tempWordList:
                probableSets.append(dictWords)
                tempWordList.append(dictWords)  # avoid every sentence in probableSets show repeat words or disappear some words
                print(dictWords)
    tempWordList = []
    
sentenceIndex = [i for i,v in enumerate(probableSets) if v=='，']
# Out:
# 禿
# 禿頭
# 頭
# 除
# 與
# 家
# 家族
# 家族史
# 族
# 史
# 有
# 有關
# 關
# ，
# 毛
# 毛囊炎
# 囊
# 炎
# 也
# 是
# 一
# 一大
# 大
# 原
# 原因
# 因
# ，
# 如
# 如果
# 果
# 頭
# 頭皮
# 皮
# 摸
# 摸起來
# 起
# 起來
# 來
# 好
# 好像
# 像
# 長
# 痘
# 痘痘
# ，
# 有
# 一
# 一顆顆
# 顆
# 顆顆
# 還
# 伴
# 伴隨
# 隨
# 刺
# 刺痛
# 痛
# ，
# 就
# 有
# 可
# 可能
# 能
# 是
# 毛
# 毛囊炎
# 囊
# 炎
# ，
# 應
# 少
# 用
# 太
# 緊
# 的
# 帽
# 帽子
# 子
# ，
# 也
# 避
# 避免
# 免
# 安
# 安全
# 安全帽
# 全
# 帽
# 戴
# 太
# 久
# ，
# 以
# 以免
# 免
# 毛
# 毛囊炎
# 囊
# 炎
# 惡
# 惡化
# 化
# 。
# 夏
# 夏天
# 天
# 或
# 熱
# 時
# 較
# 易
# 出
# 出現
# 現
# 毛
# 毛囊炎
# 囊
# 炎
# ，
# 醫
# 醫師
# 師
# 確
# 確診
# 診
# 後
# 應
# 會
# 開
# 開立
# 立
# 口
# 口服
# 服
# 抗
# 抗生素
# 生
# 素
# 藥
# 藥物
# 物
# ；
# 若
# 紅
# 紅腫
# 腫
# 較
# 較少
# 少
# 則
# 塗
# 塗抹
# 抹
# 外
# 外用
# 用
# 用藥
# 藥
# 藥膏
# 膏
# 即
# 即可
# 可
# 可望
# 望
# 逐
# 逐漸
# 漸
# 改
# 改善
# 善
# 症
# 症狀
# 狀
# 。
# 美
# 美國
# 國
# 總
# 總統
# 統
# 川
# 川普
# 普
# 昨
# 在
# 越
# 越南
# 南
# 南海
# 表
# 表示
# 示
# 願
# 願意
# 意
# 調
# 調停
# 停
# 海
# 爭
# 爭議
# 議
# ，
# 隨
# 隨後
# 後
# 最後
# 轉
# 轉往
# 往
# 菲
# 菲律賓
# 律
# 賓
# ，
# 展
# 展開
# 開
# 亞
# 亞洲
# 洲
# 之
# 行
# 行程
# 最
# 一
# 站
# 程
# 參
# 參加
# ...

# %%
sentenceIndex
# Out:
# [13, 26, 44, 57, 68, 78, 91, 118, 203, 215, 284, 346, 361, 392, 420]

# %%
probableSets[:sentenceIndex[0]+1]
# Out:
# ['禿', '禿頭', '頭', '除', '與', '家', '家族', '家族史', '族', '史', '有', '有關', '關', '，']

# %%
firstSets = ['禿 頭','禿頭']
secondSets = ['家 族 史','家族 史','家族史']
thirdSets = ['有 關 ，','有關 ，']

stableStr1 = '除 與'

answerWords = []
ansCheckIndex = 0

for i in firstSets:
    answer = ''
    
    for j in secondSets:
        
        for k in thirdSets:

            answer = i + ' ' + stableStr1 + ' ' + j +' '+ k
            # ensure the answer is not repeat
            if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 12
#
#
# 禿 頭 除 與 家 族 史 有 關 ，
# 禿 頭 除 與 家 族 史 有關 ，
# 禿 頭 除 與 家族 史 有 關 ，
# 禿 頭 除 與 家族 史 有關 ，
# 禿 頭 除 與 家族史 有 關 ，
# 禿 頭 除 與 家族史 有關 ，
# 禿頭 除 與 家 族 史 有 關 ，
# 禿頭 除 與 家 族 史 有關 ，
# 禿頭 除 與 家族 史 有 關 ，
# 禿頭 除 與 家族 史 有關 ，
# 禿頭 除 與 家族史 有 關 ，
# 禿頭 除 與 家族史 有關 ，

# %%
probableSets[sentenceIndex[0]+1:sentenceIndex[1]+1]
# Out:
# ['毛', '毛囊炎', '囊', '炎', '也', '是', '一', '一大', '大', '原', '原因', '因', '，']

# %%
firstSets = ['毛 囊 炎','毛囊炎']
secondSets = ['一 大','一大']
thirdSets = ['原 因 ，','原因 ，']

stableStr1 = '也 是'

answerWords = []
ansCheckIndex = 1

for i in firstSets:
    answer = ''
    
    for j in secondSets:
        
        for k in thirdSets:

            answer = i + ' ' + stableStr1 + ' ' + j +' '+ k
            # ensure the answer is not repeat
            if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 8
#
#
# 毛 囊 炎 也 是 一 大 原 因 ，
# 毛 囊 炎 也 是 一 大 原因 ，
# 毛 囊 炎 也 是 一大 原 因 ，
# 毛 囊 炎 也 是 一大 原因 ，
# 毛囊炎 也 是 一 大 原 因 ，
# 毛囊炎 也 是 一 大 原因 ，
# 毛囊炎 也 是 一大 原 因 ，
# 毛囊炎 也 是 一大 原因 ，

# %%
probableSets[sentenceIndex[1]+1:sentenceIndex[2]+1]
# Out:
# ['如',
#  '如果',
#  '果',
#  '頭',
#  '頭皮',
#  '皮',
#  '摸',
#  '摸起來',
#  '起',
#  '起來',
#  '來',
#  '好',
#  '好像',
#  '像',
#  '長',
#  '痘',
#  '痘痘',
#  '，']

# %%
firstSets = ['如 果','如果']
secondSets = ['頭 皮','頭皮']
thirdSets = ['摸 起 來','摸起來','摸 起來']
fourthSets = ['好 像','好像']
fifthSets = ['痘 痘 ，','痘痘 ，']

stableStr1 = '長'

answerWords = []
ansCheckIndex = 2

for i in firstSets:
    answer = ''
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets:

                    answer = i + ' ' + j + ' ' + k +' '+ x + ' ' + stableStr1 + ' ' + y
                # ensure the answer is not repeat
                # print(answer)
                    if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                        answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 48
#
#
# 如 果 頭 皮 摸 起 來 好 像 長 痘 痘 ，
# 如 果 頭 皮 摸 起 來 好 像 長 痘痘 ，
# 如 果 頭 皮 摸 起 來 好像 長 痘 痘 ，
# 如 果 頭 皮 摸 起 來 好像 長 痘痘 ，
# 如 果 頭 皮 摸起來 好 像 長 痘 痘 ，
# 如 果 頭 皮 摸起來 好 像 長 痘痘 ，
# 如 果 頭 皮 摸起來 好像 長 痘 痘 ，
# 如 果 頭 皮 摸起來 好像 長 痘痘 ，
# 如 果 頭 皮 摸 起來 好 像 長 痘 痘 ，
# 如 果 頭 皮 摸 起來 好 像 長 痘痘 ，
# 如 果 頭 皮 摸 起來 好像 長 痘 痘 ，
# 如 果 頭 皮 摸 起來 好像 長 痘痘 ，
# 如 果 頭皮 摸 起 來 好 像 長 痘 痘 ，
# 如 果 頭皮 摸 起 來 好 像 長 痘痘 ，
# 如 果 頭皮 摸 起 來 好像 長 痘 痘 ，
# 如 果 頭皮 摸 起 來 好像 長 痘痘 ，
# 如 果 頭皮 摸起來 好 像 長 痘 痘 ，
# 如 果 頭皮 摸起來 好 像 長 痘痘 ，
# 如 果 頭皮 摸起來 好像 長 痘 痘 ，
# 如 果 頭皮 摸起來 好像 長 痘痘 ，
# 如 果 頭皮 摸 起來 好 像 長 痘 痘 ，
# 如 果 頭皮 摸 起來 好 像 長 痘痘 ，
# 如 果 頭皮 摸 起來 好像 長 痘 痘 ，
# 如 果 頭皮 摸 起來 好像 長 痘痘 ，
# 如果 頭 皮 摸 起 來 好 像 長 痘 痘 ，
# 如果 頭 皮 摸 起 來 好 像 長 痘痘 ，
# 如果 頭 皮 摸 起 來 好像 長 痘 痘 ，
# 如果 頭 皮 摸 起 來 好像 長 痘痘 ，
# 如果 頭 皮 摸起來 好 像 長 痘 痘 ，
# 如果 頭 皮 摸起來 好 像 長 痘痘 ，
# 如果 頭 皮 摸起來 好像 長 痘 痘 ，
# 如果 頭 皮 摸起來 好像 長 痘痘 ，
# 如果 頭 皮 摸 起來 好 像 長 痘 痘 ，
# 如果 頭 皮 摸 起來 好 像 長 痘痘 ，
# 如果 頭 皮 摸 起來 好像 長 痘 痘 ，
# 如果 頭 皮 摸 起來 好像 長 痘痘 ，
# 如果 頭皮 摸 起 來 好 像 長 痘 痘 ，
# 如果 頭皮 摸 起 來 好 像 長 痘痘 ，
# ...

# %%
probableSets[sentenceIndex[2]+1:sentenceIndex[3]+1]
# Out:
# ['有', '一', '一顆顆', '顆', '顆顆', '還', '伴', '伴隨', '隨', '刺', '刺痛', '痛', '，']

# %%
firstSets = ['一 顆 顆','一 顆顆','一顆顆']
secondSets = ['伴 隨','伴隨']
thirdSets = ['刺 痛 ，','刺痛 ，']

stableStr1 = '有'
stableStr2 = '還'

answerWords = []
ansCheckIndex = 3

for i in firstSets:
    answer = ''
    
    for j in secondSets:
        
        for k in thirdSets:
            answer = stableStr1 + ' ' + i + ' ' + stableStr2 +' '+ j + ' ' + k
            # ensure the answer is not repeat
            
            if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 12
#
#
# 有 一 顆 顆 還 伴 隨 刺 痛 ，
# 有 一 顆 顆 還 伴 隨 刺痛 ，
# 有 一 顆 顆 還 伴隨 刺 痛 ，
# 有 一 顆 顆 還 伴隨 刺痛 ，
# 有 一 顆顆 還 伴 隨 刺 痛 ，
# 有 一 顆顆 還 伴 隨 刺痛 ，
# 有 一 顆顆 還 伴隨 刺 痛 ，
# 有 一 顆顆 還 伴隨 刺痛 ，
# 有 一顆顆 還 伴 隨 刺 痛 ，
# 有 一顆顆 還 伴 隨 刺痛 ，
# 有 一顆顆 還 伴隨 刺 痛 ，
# 有 一顆顆 還 伴隨 刺痛 ，

# %%
probableSets[sentenceIndex[3]+1:sentenceIndex[4]+1]
# Out:
# ['就', '有', '可', '可能', '能', '是', '毛', '毛囊炎', '囊', '炎', '，']

# %%
firstSets = ['可 能','可能']
secondSets = ['毛 囊 炎 ，','毛囊炎 ，']

stableStr1 = '就 有'
stableStr2 = '是'

answerWords = []
ansCheckIndex = 4

for i in firstSets:
    answer = ''
    
    for j in secondSets:
        answer = stableStr1 + ' ' + i + ' ' + stableStr2 +' '+ j
        
        # ensure the answer is not repeat
        if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
            answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 4
#
#
# 就 有 可 能 是 毛 囊 炎 ，
# 就 有 可 能 是 毛囊炎 ，
# 就 有 可能 是 毛 囊 炎 ，
# 就 有 可能 是 毛囊炎 ，

# %%
probableSets[sentenceIndex[4]+1:sentenceIndex[5]+1]
# Out:
# ['應', '少', '用', '太', '緊', '的', '帽', '帽子', '子', '，']

# %%
firstSets = ['帽 子 ，','帽子 ，']

stableStr1 = '應 少 用 太 緊 的'

answerWords = []
ansCheckIndex = 5

for i in firstSets:
    answer = stableStr1 + ' ' + i
    # ensure the answer is not repeat
    if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
        answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 2
#
#
# 應 少 用 太 緊 的 帽 子 ，
# 應 少 用 太 緊 的 帽子 ，

# %%
probableSets[sentenceIndex[5]+1:sentenceIndex[6]+1]
# Out:
# ['也', '避', '避免', '免', '安', '安全', '安全帽', '全', '帽', '戴', '太', '久', '，']

# %%
firstSets = ['避 免','避免']
secondSets = ['安 全 帽' , '安全 帽','安全帽']

stableStr1 = '也'
stableStr2 = '戴 太 久 ，'

answerWords = []
ansCheckIndex = 6

for i in firstSets:
    
    for j in secondSets:
        
        answer = stableStr1 + ' ' + i + ' ' + j + ' ' + stableStr2
        
        # ensure the answer is not repeat
        if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
            answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 6
#
#
# 也 避 免 安 全 帽 戴 太 久 ，
# 也 避 免 安全 帽 戴 太 久 ，
# 也 避 免 安全帽 戴 太 久 ，
# 也 避免 安 全 帽 戴 太 久 ，
# 也 避免 安全 帽 戴 太 久 ，
# 也 避免 安全帽 戴 太 久 ，

# %%
probableSets[sentenceIndex[6]+1:sentenceIndex[7]+1]
# Out:
# ['以',
#  '以免',
#  '免',
#  '毛',
#  '毛囊炎',
#  '囊',
#  '炎',
#  '惡',
#  '惡化',
#  '化',
#  '。',
#  '夏',
#  '夏天',
#  '天',
#  '或',
#  '熱',
#  '時',
#  '較',
#  '易',
#  '出',
#  '出現',
#  '現',
#  '毛',
#  '毛囊炎',
#  '囊',
#  '炎',
#  '，']

# %%
firstSets = ['以 免','以免']
secondSets = ['毛 囊 炎', '毛囊炎']
thirdSets = ['惡 化 。','惡化 。']

answerWords = []
ansCheckIndex = 7

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            answer = i + ' ' + j + ' ' + k
        
        # ensure the answer is not repeat
            if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 8
#
#
# 以 免 毛 囊 炎 惡 化 。
# 以 免 毛 囊 炎 惡化 。
# 以 免 毛囊炎 惡 化 。
# 以 免 毛囊炎 惡化 。
# 以免 毛 囊 炎 惡 化 。
# 以免 毛 囊 炎 惡化 。
# 以免 毛囊炎 惡 化 。
# 以免 毛囊炎 惡化 。

# %%
firstSets = ['夏 天','夏天']
secondSets = ['出 現', '出現']
thirdSets = ['毛 囊 炎 ，', '毛囊炎 ，']

stableStr1 = '或 天 熱 時 較 易'

answerWords = []
ansCheckIndex = 8

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            answer = i + ' ' + stableStr1 + ' ' + j + ' ' + k
            
        # ensure the answer is not repeat
            if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 8
#
#
# 夏 天 或 天 熱 時 較 易 出 現 毛 囊 炎 ，
# 夏 天 或 天 熱 時 較 易 出 現 毛囊炎 ，
# 夏 天 或 天 熱 時 較 易 出現 毛 囊 炎 ，
# 夏 天 或 天 熱 時 較 易 出現 毛囊炎 ，
# 夏天 或 天 熱 時 較 易 出 現 毛 囊 炎 ，
# 夏天 或 天 熱 時 較 易 出 現 毛囊炎 ，
# 夏天 或 天 熱 時 較 易 出現 毛 囊 炎 ，
# 夏天 或 天 熱 時 較 易 出現 毛囊炎 ，

# %%
probableSets[sentenceIndex[7]+1:sentenceIndex[8]+1]
# Out:
# ['醫',
#  '醫師',
#  '師',
#  '確',
#  '確診',
#  '診',
#  '後',
#  '應',
#  '會',
#  '開',
#  '開立',
#  '立',
#  '口',
#  '口服',
#  '服',
#  '抗',
#  '抗生素',
#  '生',
#  '素',
#  '藥',
#  '藥物',
#  '物',
#  '；',
#  '若',
#  '紅',
#  '紅腫',
#  '腫',
#  '較',
#  '較少',
#  '少',
#  '則',
#  '塗',
#  '塗抹',
#  '抹',
#  '外',
#  '外用',
#  '用',
#  '用藥',
#  '藥',
#  '藥膏',
#  '膏',
#  '即',
#  '即可',
#  '可',
#  '可望',
#  '望',
#  '逐',
#  '逐漸',
#  '漸',
#  '改',
#  '改善',
#  '善',
#  '症',
#  '症狀',
#  '狀',
#  '。',
#  '美',
#  '美國',
#  '國',
#  '總',
#  '總統',
#  '統',
#  '川',
#  '川普',
#  '普',
#  '昨',
#  '在',
#  '越',
#  '越南',
#  '南',
#  '南海',
#  '表',
#  '表示',
#  '示',
#  '願',
#  '願意',
#  '意',
#  '調',
#  '調停',
#  '停',
#  '海',
#  '爭',
#  '爭議',
#  '議',
#  '，']

# %%
firstSets = ['醫 師','醫師']
secondSets = ['確 診', '確診']
thirdSets = ['開 立', '開立']
fourthSets = ['口 服', '口服']
fifthSets = ['抗 生 素', '抗生素']
sixthSets = ['藥 物 ；', '藥物 ；']

stableStr1 = '後 應 會'

answerWords = []
ansCheckIndex = 9

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    
                    for z in sixthSets:
                        
                        answer = i + ' ' + j + ' ' + stableStr1 + ' ' + k + ' ' + x + ' ' + y + ' ' + z
            
                        # ensure the answer is not repeat
                        if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                            answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 64
#
#
# 醫 師 確 診 後 應 會 開 立 口 服 抗 生 素 藥 物 ；
# 醫 師 確 診 後 應 會 開 立 口 服 抗 生 素 藥物 ；
# 醫 師 確 診 後 應 會 開 立 口 服 抗生素 藥 物 ；
# 醫 師 確 診 後 應 會 開 立 口 服 抗生素 藥物 ；
# 醫 師 確 診 後 應 會 開 立 口服 抗 生 素 藥 物 ；
# 醫 師 確 診 後 應 會 開 立 口服 抗 生 素 藥物 ；
# 醫 師 確 診 後 應 會 開 立 口服 抗生素 藥 物 ；
# 醫 師 確 診 後 應 會 開 立 口服 抗生素 藥物 ；
# 醫 師 確 診 後 應 會 開立 口 服 抗 生 素 藥 物 ；
# 醫 師 確 診 後 應 會 開立 口 服 抗 生 素 藥物 ；
# 醫 師 確 診 後 應 會 開立 口 服 抗生素 藥 物 ；
# 醫 師 確 診 後 應 會 開立 口 服 抗生素 藥物 ；
# 醫 師 確 診 後 應 會 開立 口服 抗 生 素 藥 物 ；
# 醫 師 確 診 後 應 會 開立 口服 抗 生 素 藥物 ；
# 醫 師 確 診 後 應 會 開立 口服 抗生素 藥 物 ；
# 醫 師 確 診 後 應 會 開立 口服 抗生素 藥物 ；
# 醫 師 確診 後 應 會 開 立 口 服 抗 生 素 藥 物 ；
# 醫 師 確診 後 應 會 開 立 口 服 抗 生 素 藥物 ；
# 醫 師 確診 後 應 會 開 立 口 服 抗生素 藥 物 ；
# 醫 師 確診 後 應 會 開 立 口 服 抗生素 藥物 ；
# 醫 師 確診 後 應 會 開 立 口服 抗 生 素 藥 物 ；
# 醫 師 確診 後 應 會 開 立 口服 抗 生 素 藥物 ；
# 醫 師 確診 後 應 會 開 立 口服 抗生素 藥 物 ；
# 醫 師 確診 後 應 會 開 立 口服 抗生素 藥物 ；
# 醫 師 確診 後 應 會 開立 口 服 抗 生 素 藥 物 ；
# 醫 師 確診 後 應 會 開立 口 服 抗 生 素 藥物 ；
# 醫 師 確診 後 應 會 開立 口 服 抗生素 藥 物 ；
# 醫 師 確診 後 應 會 開立 口 服 抗生素 藥物 ；
# 醫 師 確診 後 應 會 開立 口服 抗 生 素 藥 物 ；
# ...

# %%
firstSets = ['若 紅 腫','若 紅腫']
secondSets = ['較 少 則', '較少 則']
thirdSets = ['塗 抹', '塗抹']
fourthSets = ['外', '外用']
fifthSets = ['用', '用藥']
sixthSets = ['藥 膏', '藥膏']
seventhSets = ['即', '即可']
eighthSets = ['可 望', '可望']
ninethSets = ['逐 漸', '逐漸']
tenthSets = ['改 善', '改善']
eleventhSets = ['症 狀 。', '症狀 。']

answerWords = []
ansCheckIndex = 10

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    yy = check(x,y,'')
                    
                    for z in sixthSets:
                        
                        for s in seventhSets:
                            
                            for d in eighthSets:
                                dd = check(s,d,'望')
                                
                                for f in ninethSets:
                                    
                                    for g in tenthSets:
                                        
                                        for h in eleventhSets:
                        
                                            answer = i + ' ' + j + ' ' + k + ' ' + x + ' ' + yy + ' ' + z + ' ' + s + ' ' + dd + ' ' + f + ' ' + g + ' ' + h
                                            #print(answer)
                                            # ensure the answer is not repeat
                                            if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                                                answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 768
#
#
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可 望 逐 漸 改 善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可 望 逐 漸 改 善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可 望 逐 漸 改善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可 望 逐 漸 改善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可 望 逐漸 改 善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可 望 逐漸 改 善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可 望 逐漸 改善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可 望 逐漸 改善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可望 逐 漸 改 善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可望 逐 漸 改 善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可望 逐 漸 改善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可望 逐 漸 改善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可望 逐漸 改 善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可望 逐漸 改 善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可望 逐漸 改善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即 可望 逐漸 改善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即可 望 逐 漸 改 善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即可 望 逐 漸 改 善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即可 望 逐 漸 改善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即可 望 逐 漸 改善 症狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即可 望 逐漸 改 善 症 狀 。
# 若 紅 腫 較 少 則 塗 抹 外 用 藥 膏 即可 望 逐漸 改 善 症狀 。
# ...

# %%
firstSets = ['美 國','美國']
secondSets = ['總 統', '總統']
thirdSets = ['川 普 昨 在', '川普 昨 在']
fourthSets = ['越 南', '越南']
fifthSets = ['南 海', '南海']
sixthSets = ['表 示', '表示']
seventhSets = ['願 意', '願意']
eighthSets = ['調 停', '調停']
ninethSets = ['南 海', '南海']
tenthSets = ['爭 議 ，', '爭議 ，']

answerWords = []
ansCheckIndex = 11

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    yy = ''
                    
                    for z in sixthSets:
                        
                        for s in seventhSets:
                            
                            for d in eighthSets:
                                dd = check(s,d,'望')
                                
                                for f in ninethSets:
                                    
                                    for g in tenthSets:
                        
                                        answer = i + ' ' + j + ' ' + k + ' ' + x + ' ' + yy + ' ' + z + ' ' + s + ' ' + dd + ' ' + f + ' ' + g
                                        # ensure the answer is not repeat
                                        if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                                            answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 256
#
#
# 美 國 總 統 川 普 昨 在 越 南  表 示 願 意 調 停 南 海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越 南  表 示 願 意 調 停 南 海 爭議 ，
# 美 國 總 統 川 普 昨 在 越 南  表 示 願 意 調 停 南海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越 南  表 示 願 意 調 停 南海 爭議 ，
# 美 國 總 統 川 普 昨 在 越 南  表 示 願 意 調停 南 海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越 南  表 示 願 意 調停 南 海 爭議 ，
# 美 國 總 統 川 普 昨 在 越 南  表 示 願 意 調停 南海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越 南  表 示 願 意 調停 南海 爭議 ，
# 美 國 總 統 川 普 昨 在 越 南  表示 願 意 調 停 南 海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越 南  表示 願 意 調 停 南 海 爭議 ，
# 美 國 總 統 川 普 昨 在 越 南  表示 願 意 調 停 南海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越 南  表示 願 意 調 停 南海 爭議 ，
# 美 國 總 統 川 普 昨 在 越 南  表示 願 意 調停 南 海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越 南  表示 願 意 調停 南 海 爭議 ，
# 美 國 總 統 川 普 昨 在 越 南  表示 願 意 調停 南海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越 南  表示 願 意 調停 南海 爭議 ，
# 美 國 總 統 川 普 昨 在 越南  表 示 願 意 調 停 南 海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越南  表 示 願 意 調 停 南 海 爭議 ，
# 美 國 總 統 川 普 昨 在 越南  表 示 願 意 調 停 南海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越南  表 示 願 意 調 停 南海 爭議 ，
# 美 國 總 統 川 普 昨 在 越南  表 示 願 意 調停 南 海 爭 議 ，
# 美 國 總 統 川 普 昨 在 越南  表 示 願 意 調停 南 海 爭議 ，
# ...

# %%
# list the probable word sets
probableSets = []
seq = 1
sentenceI = 12
for word in splitInput[sentenceI]:
    for dictWords in splitDict:
        if dictWords == word or dictWords == word+splitInput[sentenceI][seq] or dictWords == word+splitInput[sentenceI][seq]+splitInput[sentenceI][seq+1]:
            probableSets.append(dictWords)
            print(dictWords)
    if seq < (len(splitInput[sentenceI])-2):
        seq = seq + 1
# Out:
# 隨
# 隨後
# 後
# 轉
# 轉往
# 往
# 菲
# 菲律賓
# 律
# 賓
# ，
# 展
# 展開
# 開
# 亞
# 亞洲
# 洲
# 之
# 行
# 最
# 最後
# 後
# 一
# 站
# 行
# 行程
# 程
# ，

# %%
firstSets = ['隨 後','隨後']
secondSets = ['轉 往', '轉往']
thirdSets = ['菲 律 賓 ，','菲律賓 ，']
fourthSets = ['展 開', '展開']
fifthSets = ['亞 洲 之 行', '亞洲 之 行']
sixthSets = ['最 後 一 站', '最後 一 站']
seventhSets = ['行 程 ，', '行程 ，']

answerWords = []
ansCheckIndex = 12

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    
                    for z in sixthSets:
                        
                        for s in seventhSets:
            
                            answer = i + ' ' + j + ' ' + k + ' ' + x + ' ' + y + ' ' + z + ' ' + s
         
                            # ensure the answer is not repeat
                            if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                                answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 128
#
#
# 隨 後 轉 往 菲 律 賓 ， 展 開 亞 洲 之 行 最 後 一 站 行 程 ，
# 隨 後 轉 往 菲 律 賓 ， 展 開 亞 洲 之 行 最 後 一 站 行程 ，
# 隨 後 轉 往 菲 律 賓 ， 展 開 亞 洲 之 行 最後 一 站 行 程 ，
# 隨 後 轉 往 菲 律 賓 ， 展 開 亞 洲 之 行 最後 一 站 行程 ，
# 隨 後 轉 往 菲 律 賓 ， 展 開 亞洲 之 行 最 後 一 站 行 程 ，
# 隨 後 轉 往 菲 律 賓 ， 展 開 亞洲 之 行 最 後 一 站 行程 ，
# 隨 後 轉 往 菲 律 賓 ， 展 開 亞洲 之 行 最後 一 站 行 程 ，
# 隨 後 轉 往 菲 律 賓 ， 展 開 亞洲 之 行 最後 一 站 行程 ，
# 隨 後 轉 往 菲 律 賓 ， 展開 亞 洲 之 行 最 後 一 站 行 程 ，
# 隨 後 轉 往 菲 律 賓 ， 展開 亞 洲 之 行 最 後 一 站 行程 ，
# 隨 後 轉 往 菲 律 賓 ， 展開 亞 洲 之 行 最後 一 站 行 程 ，
# 隨 後 轉 往 菲 律 賓 ， 展開 亞 洲 之 行 最後 一 站 行程 ，
# 隨 後 轉 往 菲 律 賓 ， 展開 亞洲 之 行 最 後 一 站 行 程 ，
# 隨 後 轉 往 菲 律 賓 ， 展開 亞洲 之 行 最 後 一 站 行程 ，
# 隨 後 轉 往 菲 律 賓 ， 展開 亞洲 之 行 最後 一 站 行 程 ，
# 隨 後 轉 往 菲 律 賓 ， 展開 亞洲 之 行 最後 一 站 行程 ，
# 隨 後 轉 往 菲律賓 ， 展 開 亞 洲 之 行 最 後 一 站 行 程 ，
# 隨 後 轉 往 菲律賓 ， 展 開 亞 洲 之 行 最 後 一 站 行程 ，
# 隨 後 轉 往 菲律賓 ， 展 開 亞 洲 之 行 最後 一 站 行 程 ，
# 隨 後 轉 往 菲律賓 ， 展 開 亞 洲 之 行 最後 一 站 行程 ，
# 隨 後 轉 往 菲律賓 ， 展 開 亞洲 之 行 最 後 一 站 行 程 ，
# 隨 後 轉 往 菲律賓 ， 展 開 亞洲 之 行 最 後 一 站 行程 ，
# 隨 後 轉 往 菲律賓 ， 展 開 亞洲 之 行 最後 一 站 行 程 ，
# ...

# %%
# list the probable word sets
probableSets = []
seq = 1
sentenceI = 13
for word in splitInput[sentenceI]:
    for dictWords in splitDict:
        if dictWords == word or dictWords == word+splitInput[sentenceI][seq] or dictWords == word+splitInput[sentenceI][seq]+splitInput[sentenceI][seq+1]:
            probableSets.append(dictWords)
            print(dictWords)
    if seq < (len(splitInput[sentenceI])-2):
        seq = seq + 1
# Out:
# 參
# 參加
# 加
# 東
# 東南
# 東南亞
# 南
# 南亞
# 亞
# 及
# 東
# 東亞
# 亞
# 國
# 國家
# 家
# 的
# 高
# 高峰
# 高峰會
# 峰
# 會
# 。

# %%
firstSets = ['參 加','參加']
secondSets = ['東 南 亞 及' ,'東 南亞 及', '東南 亞 及','東南亞 及']
thirdSets = ['東 亞','東亞']
fourthSets = ['國 家 的', '國家 的']
fifthSets = ['高 峰 會 。', '高峰 會 。', '高峰會 。']

answerWords = []
ansCheckIndex = 13

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    answer = i + ' ' + j + ' ' + k + ' ' + x + ' ' + y
                    # ensure the answer is not repeat
                    if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                        answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 96
#
#
# 參 加 東 南 亞 及 東 亞 國 家 的 高 峰 會 。
# 參 加 東 南 亞 及 東 亞 國 家 的 高峰 會 。
# 參 加 東 南 亞 及 東 亞 國 家 的 高峰會 。
# 參 加 東 南 亞 及 東 亞 國家 的 高 峰 會 。
# 參 加 東 南 亞 及 東 亞 國家 的 高峰 會 。
# 參 加 東 南 亞 及 東 亞 國家 的 高峰會 。
# 參 加 東 南 亞 及 東亞 國 家 的 高 峰 會 。
# 參 加 東 南 亞 及 東亞 國 家 的 高峰 會 。
# 參 加 東 南 亞 及 東亞 國 家 的 高峰會 。
# 參 加 東 南 亞 及 東亞 國家 的 高 峰 會 。
# 參 加 東 南 亞 及 東亞 國家 的 高峰 會 。
# 參 加 東 南 亞 及 東亞 國家 的 高峰會 。
# 參 加 東 南亞 及 東 亞 國 家 的 高 峰 會 。
# 參 加 東 南亞 及 東 亞 國 家 的 高峰 會 。
# 參 加 東 南亞 及 東 亞 國 家 的 高峰會 。
# 參 加 東 南亞 及 東 亞 國家 的 高 峰 會 。
# 參 加 東 南亞 及 東 亞 國家 的 高峰 會 。
# 參 加 東 南亞 及 東 亞 國家 的 高峰會 。
# 參 加 東 南亞 及 東亞 國 家 的 高 峰 會 。
# 參 加 東 南亞 及 東亞 國 家 的 高峰 會 。
# 參 加 東 南亞 及 東亞 國 家 的 高峰會 。
# 參 加 東 南亞 及 東亞 國家 的 高 峰 會 。
# 參 加 東 南亞 及 東亞 國家 的 高峰 會 。
# 參 加 東 南亞 及 東亞 國家 的 高峰會 。
# 參 加 東南 亞 及 東 亞 國 家 的 高 峰 會 。
# 參 加 東南 亞 及 東 亞 國 家 的 高峰 會 。
# 參 加 東南 亞 及 東 亞 國 家 的 高峰會 。
# 參 加 東南 亞 及 東 亞 國家 的 高 峰 會 。
# 參 加 東南 亞 及 東 亞 國家 的 高峰 會 。
# 參 加 東南 亞 及 東 亞 國家 的 高峰會 。
# 參 加 東南 亞 及 東亞 國 家 的 高 峰 會 。
# 參 加 東南 亞 及 東亞 國 家 的 高峰 會 。
# ...

# %%
# list the probable word sets
probableSets = []
seq = 1
sentenceI = 14
for word in splitInput[sentenceI]:
    for dictWords in splitDict:
        if dictWords == word or dictWords == word+splitInput[sentenceI][seq] or dictWords == word+splitInput[sentenceI][seq]+splitInput[sentenceI][seq+1]:
            probableSets.append(dictWords)
            print(dictWords)
    if seq < (len(splitInput[sentenceI])-2):
        seq = seq + 1
# Out:
# 菲
# 菲律賓
# 律
# 賓
# 總
# 總統
# 統
# 杜
# 杜特蒂
# 特
# 蒂
# 昨
# 重
# 重申
# 申
# 別
# 惹
# 中
# 中國
# 國
# 、
# 擱
# 擱置
# 置
# 主
# 主權
# 權
# 爭
# 爭議
# 議
# 的
# 立
# 立場
# 場
# ，

# %%
firstSets = ['菲 律 賓','菲律賓']
secondSets = ['總 統' ,'總統']
thirdSets = ['杜 特 蒂 昨','杜特蒂 昨']
fourthSets = ['重 申 別 惹', '重申 別 惹']
fifthSets = ['中 國 、', '中國 、']
sixthSets = ['擱 置', '擱置']
seventhSets = ['主 權', '主權']
eighthSets = ['爭 議 的', '爭議 的']
ninethSets = ['立 場 ，', '立場 ，']

answerWords = []
ansCheckIndex = 14

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    
                    for z in sixthSets: 
                        
                        for s in seventhSets: 
                            
                            for d in eighthSets: 
                                
                                for f in ninethSets: 
                                    answer = i + ' ' + j + ' ' + k + ' ' + x + ' ' + y + ' ' + z + ' ' + s + ' ' + d + ' ' + f
                                    # ensure the answer is not repeat
                                    # print(answer)
                                    if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                                        answerWords.append(answer)
                                        
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 512
#
#
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱 置 主 權 爭 議 的 立 場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱 置 主 權 爭 議 的 立場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱 置 主 權 爭議 的 立 場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱 置 主 權 爭議 的 立場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱 置 主權 爭 議 的 立 場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱 置 主權 爭 議 的 立場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱 置 主權 爭議 的 立 場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱 置 主權 爭議 的 立場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱置 主 權 爭 議 的 立 場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱置 主 權 爭 議 的 立場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱置 主 權 爭議 的 立 場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱置 主 權 爭議 的 立場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱置 主權 爭 議 的 立 場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱置 主權 爭 議 的 立場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱置 主權 爭議 的 立 場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中 國 、 擱置 主權 爭議 的 立場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中國 、 擱 置 主 權 爭 議 的 立 場 ，
# 菲 律 賓 總 統 杜 特 蒂 昨 重 申 別 惹 中國 、 擱 置 主 權 爭 議 的 立場 ，
# ...

# %%
# list the probable word sets
probableSets = []
seq = 1
sentenceI = 15
for word in splitInput[sentenceI]:
    for dictWords in splitDict:
        if dictWords == word or dictWords == word+splitInput[sentenceI][seq] or dictWords == word+splitInput[sentenceI][seq]+splitInput[sentenceI][seq+1]:
            probableSets.append(dictWords)
            print(dictWords)
    if seq < (len(splitInput[sentenceI])-2):
        seq = seq + 1
# Out:
# 還
# 說
# 獲
# 中
# 中國
# 國
# 國
# 國家
# 家
# 主
# 主席
# 席
# 習
# 習近平
# 近
# 平
# 保
# 保證
# 證
# 會
# 和
# 和平
# 平
# 解
# 解決
# 決
# 南
# 南海
# 海
# 問
# 問題
# 題
# 。

# %%
firstSets = ['還 說 獲 中 國','還 說 獲 中國']
secondSets = ['國 家' ,'國家']
thirdSets = ['主 席','主席']
fourthSets = ['習 近 平', '習近平']
fifthSets = ['保 證 會', '保證 會']
sixthSets = ['和 平', '和平']
seventhSets = ['解 決', '解決']
eighthSets = ['南 海', '南海']
ninethSets = ['問 題 。', '問題 。']

answerWords = []
ansCheckIndex = 15

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    
                    for z in sixthSets: 
                        
                        for s in seventhSets: 
                            
                            for d in eighthSets: 
                                
                                for f in ninethSets: 
                                    answer = i + ' ' + j + ' ' + k + ' ' + x + ' ' + y + ' ' + z + ' ' + s + ' ' + d + ' ' + f
                                    # ensure the answer is not repeat
                                    # print(answer)
                                    if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                                        answerWords.append(answer)
                                        
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 512
#
#
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和 平 解 決 南 海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和 平 解 決 南 海 問題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和 平 解 決 南海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和 平 解 決 南海 問題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和 平 解決 南 海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和 平 解決 南 海 問題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和 平 解決 南海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和 平 解決 南海 問題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和平 解 決 南 海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和平 解 決 南 海 問題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和平 解 決 南海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和平 解 決 南海 問題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和平 解決 南 海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和平 解決 南 海 問題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和平 解決 南海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保 證 會 和平 解決 南海 問題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保證 會 和 平 解 決 南 海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保證 會 和 平 解 決 南 海 問題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保證 會 和 平 解 決 南海 問 題 。
# 還 說 獲 中 國 國 家 主 席 習 近 平 保證 會 和 平 解 決 南海 問題 。
# ...

# %%
# list the probable word sets
probableSets = []
sentenceI = 16

for word in splitInput[sentenceI]:
    for dictWords in splitDict:
        if word in dictWords and dictWords in splitInput[sentenceI] and dictWords not in probableSets:
            probableSets.append(dictWords)
            print(dictWords)
# Out:
# 在
# 南
# 南海
# 海
# 建
# 建造
# 造
# 7
# 座
# 座人
# 人
# 人工
# 人工島礁
# 工
# 島
# 礁
# 、
# 部
# 部署
# 署
# 飛
# 飛彈
# 彈
# 戰
# 戰機
# 機
# 的
# 中
# 中國
# 國
# ，

# %%
firstSets = ['在 南 海','在 南海']
secondSets = ['建 造 7' ,'建造 7']
thirdSets = ['座','座人']
fourthSets = ['人 工 島 礁 、', '人工 島 礁 、', '人工島礁 、']
fifthSets = ['部 署', '部署']
sixthSets = ['飛 彈', '飛彈']
seventhSets = ['戰 機 的', '戰機 的']
eighthSets = ['中 國 ，', '中國 ，']

answerWords = []
ansCheckIndex = 16

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                xx = check(k,x,'工 島 礁 、')
                
                for y in fifthSets: 
                    
                    for z in sixthSets: 
                        
                        for s in seventhSets: 
                            
                            for d in eighthSets: 
                                
                                answer = i + ' ' + j + ' ' + k + ' ' + xx + ' ' + y + ' ' + z + ' ' + s + ' ' + d
                                
                                # ensure the answer is not repeat
                                if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                                    answerWords.append(answer)

print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 256
#
#
# 在 南 海 建 造 7 座 人 工 島 礁 、 部 署 飛 彈 戰 機 的 中 國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部 署 飛 彈 戰 機 的 中國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部 署 飛 彈 戰機 的 中 國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部 署 飛 彈 戰機 的 中國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部 署 飛彈 戰 機 的 中 國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部 署 飛彈 戰 機 的 中國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部 署 飛彈 戰機 的 中 國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部 署 飛彈 戰機 的 中國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部署 飛 彈 戰 機 的 中 國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部署 飛 彈 戰 機 的 中國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部署 飛 彈 戰機 的 中 國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部署 飛 彈 戰機 的 中國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部署 飛彈 戰 機 的 中 國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部署 飛彈 戰 機 的 中國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部署 飛彈 戰機 的 中 國 ，
# 在 南 海 建 造 7 座 人 工 島 礁 、 部署 飛彈 戰機 的 中國 ，
# 在 南 海 建 造 7 座 人工 島 礁 、 部 署 飛 彈 戰 機 的 中 國 ，
# 在 南 海 建 造 7 座 人工 島 礁 、 部 署 飛 彈 戰 機 的 中國 ，
# 在 南 海 建 造 7 座 人工 島 礁 、 部 署 飛 彈 戰機 的 中 國 ，
# 在 南 海 建 造 7 座 人工 島 礁 、 部 署 飛 彈 戰機 的 中國 ，
# 在 南 海 建 造 7 座 人工 島 礁 、 部 署 飛彈 戰 機 的 中 國 ，
# 在 南 海 建 造 7 座 人工 島 礁 、 部 署 飛彈 戰 機 的 中國 ，
# ...

# %%
# list the probable word sets
probableSets = []
sentenceI = 17

for word in splitInput[sentenceI]:
    for dictWords in splitDict:
        if word in dictWords and dictWords in splitInput[sentenceI] and dictWords not in probableSets:
            probableSets.append(dictWords)
            print(dictWords)
# Out:
# 想
# 各
# 個
# 擊
# 擊破
# 破
# 南
# 南海
# 海
# 周
# 周邊
# 邊
# 諸
# 國
# ，

# %%
firstSets = ['想 各 個 擊 破','想 各 個 擊破']
secondSets = ['南 海', '南海']
thirdSets = ['周 邊 諸 國，', '周邊 諸 國 ，']

answerWords = []
ansCheckIndex = 17

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            answer = i  + ' ' + j + ' ' + k
            
        # ensure the answer is not repeat
            if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                answerWords.append(answer)
                
print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 8
#
#
# 想 各 個 擊 破 南 海 周 邊 諸 國，
# 想 各 個 擊 破 南 海 周邊 諸 國 ，
# 想 各 個 擊 破 南海 周 邊 諸 國，
# 想 各 個 擊 破 南海 周邊 諸 國 ，
# 想 各 個 擊破 南 海 周 邊 諸 國，
# 想 各 個 擊破 南 海 周邊 諸 國 ，
# 想 各 個 擊破 南海 周 邊 諸 國，
# 想 各 個 擊破 南海 周邊 諸 國 ，

# %%
# list the probable word sets
probableSets = []
seq = 1
sentenceI = 18
for word in splitInput[sentenceI]:
    for dictWords in splitDict:
        if dictWords == word or dictWords == word+splitInput[sentenceI][seq] or dictWords == word+splitInput[sentenceI][seq]+splitInput[sentenceI][seq+1]:
            probableSets.append(dictWords)
            print(dictWords)
    if seq < (len(splitInput[sentenceI])-2):
        seq = seq + 1
# Out:
# 堅
# 堅拒
# 拒
# 「
# 非
# 當
# 當事
# 事
# 國
# 」
# 也
# 就
# 就是
# 是
# 美
# 美國
# 國
# 或
# 日
# 日本
# 本
# 介
# 介入
# 入
# 、
# 調
# 調停
# 停
# 或
# 仲
# 仲裁
# 裁
# ，

# %%
firstSets = ['堅 拒 「 非','堅拒 「 非']
secondSets = ['當 事 國 」 也' ,'當事 國 」 也']
thirdSets = ['就 是','就是']
fourthSets = ['美 國 或', '美國 或']
fifthSets = ['日 本', '日本']
sixthSets = ['介 入 、', '介入 、']
seventhSets = ['調 停 或', '調停 或']
eighthSets = ['仲 裁 ，', '仲裁 ，']

answerWords = []
ansCheckIndex = 18

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    
                    for z in sixthSets: 
                        
                        for s in seventhSets: 
                            
                            for d in eighthSets: 
                                
                                answer = i + ' ' + j + ' ' + k + ' ' + x + ' ' + y + ' ' + z + ' ' + s + ' ' + d
                                
                                # ensure the answer is not repeat
                                if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                                    answerWords.append(answer)

print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 256
#
#
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日 本 介 入 、 調 停 或 仲 裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日 本 介 入 、 調 停 或 仲裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日 本 介 入 、 調停 或 仲 裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日 本 介 入 、 調停 或 仲裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日 本 介入 、 調 停 或 仲 裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日 本 介入 、 調 停 或 仲裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日 本 介入 、 調停 或 仲 裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日 本 介入 、 調停 或 仲裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日本 介 入 、 調 停 或 仲 裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日本 介 入 、 調 停 或 仲裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日本 介 入 、 調停 或 仲 裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日本 介 入 、 調停 或 仲裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日本 介入 、 調 停 或 仲 裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日本 介入 、 調 停 或 仲裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日本 介入 、 調停 或 仲 裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美 國 或 日本 介入 、 調停 或 仲裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美國 或 日 本 介 入 、 調 停 或 仲 裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美國 或 日 本 介 入 、 調 停 或 仲裁 ，
# 堅 拒 「 非 當 事 國 」 也 就 是 美國 或 日 本 介 入 、 調停 或 仲 裁 ，
# ...

# %%
# list the probable word sets
probableSets = []
seq = 1
sentenceI = 19
for word in splitInput[sentenceI]:
    for dictWords in splitDict:
        if dictWords == word or dictWords == word+splitInput[sentenceI][seq] or dictWords == word+splitInput[sentenceI][seq]+splitInput[sentenceI][seq+1]:
            probableSets.append(dictWords)
            print(dictWords)
    if seq < (len(splitInput[sentenceI])-2):
        seq = seq + 1
# Out:
# 美
# 美方
# 方
# 堅
# 堅持
# 持
# 各
# 國
# 在
# 南
# 南海
# 海
# 享
# 享有
# 有
# 自
# 自由
# 由
# 航
# 航行
# 行
# 與
# 飛
# 飛行
# 行
# 權
# 權利
# 利
# ，

# %%
firstSets = ['美 方','美方']
secondSets = ['堅 持 各 國 在' ,'堅持 各 國 在']
thirdSets = ['南 海','南海']
fourthSets = ['享 有', '享有']
fifthSets = ['自 由', '自由']
sixthSets = ['航 行 與', '航行 與']
seventhSets = ['飛 行', '飛行']
eighthSets = ['權 利 ，', '權利 ，']

answerWords = []
ansCheckIndex = 19

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    
                    for z in sixthSets: 
                        
                        for s in seventhSets: 
                            
                            for d in eighthSets: 
                                
                                answer = i + ' ' + j + ' ' + k + ' ' + x + ' ' + y + ' ' + z + ' ' + s + ' ' + d
                                
                                # ensure the answer is not repeat
                                if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                                    answerWords.append(answer)

print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 256
#
#
# 美 方 堅 持 各 國 在 南 海 享 有 自 由 航 行 與 飛 行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自 由 航 行 與 飛 行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自 由 航 行 與 飛行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自 由 航 行 與 飛行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自 由 航行 與 飛 行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自 由 航行 與 飛 行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自 由 航行 與 飛行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自 由 航行 與 飛行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自由 航 行 與 飛 行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自由 航 行 與 飛 行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自由 航 行 與 飛行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自由 航 行 與 飛行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自由 航行 與 飛 行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自由 航行 與 飛 行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自由 航行 與 飛行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享 有 自由 航行 與 飛行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享有 自 由 航 行 與 飛 行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享有 自 由 航 行 與 飛 行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享有 自 由 航 行 與 飛行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享有 自 由 航 行 與 飛行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享有 自 由 航行 與 飛 行 權 利 ，
# 美 方 堅 持 各 國 在 南 海 享有 自 由 航行 與 飛 行 權利 ，
# 美 方 堅 持 各 國 在 南 海 享有 自 由 航行 與 飛行 權 利 ，
# ...

# %%
# list the probable word sets
probableSets = []
seq = 1
sentenceI = 20
for word in splitInput[sentenceI]:
    for dictWords in splitDict:
        if dictWords == word or dictWords == word+splitInput[sentenceI][seq] or dictWords == word+splitInput[sentenceI][seq]+splitInput[sentenceI][seq+1]:
            probableSets.append(dictWords)
            print(dictWords)
    if seq < (len(splitInput[sentenceI])-2):
        seq = seq + 1
# Out:
# 日
# 日本
# 本
# 也
# 不
# 不想
# 想
# 讓
# 這
# 條
# 每
# 年
# 運
# 運送
# 送
# 近
# 100
# 兆
# 元
# 台
# 台幣
# 幣
# 貨
# 貨物
# 物
# 的
# 航
# 航線
# 線
# 被
# 中
# 中國
# 國
# 納
# 納為
# 為
# 內
# 內海
# 海
# 。

# %%
firstSets = ['日 本 也','日本 也']
secondSets = ['不 想 讓 這 條 每 年' ,'不想 讓 這 條 每 年']
thirdSets = ['運 送 近 100 兆 元','運送 近 100 兆 元']
fourthSets = ['台 幣', '台幣']
fifthSets = ['貨 物 的', '貨物 的']
sixthSets = ['航線 被', '航 線 被']
seventhSets = ['中 國', '中國']
eighthSets = ['納 為', '納為']
ninethSets = ['內 海 。', '內海 。']

answerWords = []
ansCheckIndex = 20

for i in firstSets:
    
    for j in secondSets:
        
        for k in thirdSets:
            
            for x in fourthSets:
                
                for y in fifthSets: 
                    
                    for z in sixthSets: 
                        
                        for s in seventhSets: 
                            
                            for d in eighthSets:
                                
                                for f in ninethSets:
                                
                                    answer = i + ' ' + j + ' ' + k + ' ' + x + ' ' + y + ' ' + z + ' ' + s + ' ' + d + ' ' + f
                                
                                    # ensure the answer is not repeat
                                    if(re.sub('\s','',answer)==splitInput[ansCheckIndex] and answer not in answerWords):  
                                        answerWords.append(answer)

print("answerWords length :",len(answerWords))
print('\n')
for answer in answerWords:
    print(answer)
# Out:
# answerWords length : 512
#
#
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航線 被 中 國 納 為 內 海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航線 被 中 國 納 為 內海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航線 被 中 國 納為 內 海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航線 被 中 國 納為 內海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航線 被 中國 納 為 內 海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航線 被 中國 納 為 內海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航線 被 中國 納為 內 海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航線 被 中國 納為 內海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航 線 被 中 國 納 為 內 海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航 線 被 中 國 納 為 內海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航 線 被 中 國 納為 內 海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航 線 被 中 國 納為 內海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航 線 被 中國 納 為 內 海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航 線 被 中國 納 為 內海 。
# 日 本 也 不 想 讓 這 條 每 年 運 送 近 100 兆 元 台 幣 貨 物 的 航 線 被 中國 納為 內 海 。
# ...
